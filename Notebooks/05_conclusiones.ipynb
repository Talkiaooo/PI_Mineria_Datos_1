# %% [markdown]
# #Conclusiones y Hallazgos Finales
# Este notebook cierra el proyecto integrador sintetizando el proceso de minería de datos aplicado. A continuación, se presentan las conclusiones extraídas del análisis exploratorio, la limpieza de datos y la reducción de dimensionalidad, vinculándolas con los objetivos de negocio planteados inicialmente.

# %% [markdown]
# ####Resumen del Proceso Realizado
# El trabajo se basó en un pipeline de datos robusto que permitió transformar un dataset original con inconsistencias en un conjunto de datos analítico limpio:
#
# ####Calidad:
# Se corrigieron valores nulos y atípicos mediante imputación por mediana y filtrado de registros inválidos.
#
# ####Análisis:
# El EDA permitió identificar que el tiempo de consumo es altamente dependiente del tipo de suscripción.
#
# ####Modelado:
# El PCA demostró ser eficaz, logrando reducir la complejidad de los datos preservando gran parte de la varianza original.

# %% [markdown]
# #Hallazgos Estratégicos
# ####Diferenciación de Clientes:
# Los usuarios con planes 'Premium' presentan un comportamiento de consumo significativamente más activo que los usuarios 'Básicos'.
#
# ####Patrones de Edad:
# La edad resultó ser una variable menos predictiva de lo esperado, sugiriendo que la preferencia de género es un factor de segmentación más importante.
#
# ####Potencial de Escalabilidad:
# El modelo de PCA desarrollado permite agrupar automáticamente a los usuarios basándose en múltiples variables simultáneas, lo cual es una herramienta potente para personalizar futuras recomendaciones.

# %% [markdown]
# #Limitaciones y Futuras Mejoras
# ####Limitaciones:
# El tamaño de la muestra original (80 registros) limita la capacidad de generalización del modelo.
#
# ####Mejoras:
# Se recomienda incorporar datos temporales más granulares y realizar un análisis de clúster (K-means) sobre los componentes principales obtenidos en el PCA para formalizar la segmentación de clientes.

# %%
print("--- RESUMEN DEL PROYECTO ---")
print("Estado del Dataset: Limpio y procesado.")
print("Reducción de Dimensionalidad: PCA (2 componentes).")
print("Hallazgo clave: Los planes de suscripción dictan el engagement.")
print("Calidad de datos: 100% de nulos tratados.")
# Out:
# --- RESUMEN DEL PROYECTO ---
# Estado del Dataset: Limpio y procesado.
# Reducción de Dimensionalidad: PCA (2 componentes).
# Hallazgo clave: Los planes de suscripción dictan el engagement.
# Calidad de datos: 100% de nulos tratados.
